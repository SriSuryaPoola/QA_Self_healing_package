# %% [markdown]
# # AegisAI Quickstart
#
# Use the SDK against a DOM snapshot when you want to test healing decisions without launching a browser.

# %%
from aegisai import AegisAI

dom = '<input id="username" type="text">'
result = AegisAI().heal_locator("//input[@id='email-field']", dom)
result.locator, result.confidence
